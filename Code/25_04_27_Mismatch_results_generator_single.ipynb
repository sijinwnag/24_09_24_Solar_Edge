# %% [markdown]
# # 1. Import & def

# %%
# imports
import os
import sys
import time
import json
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pvlib
import imageio
import datetime
from datetime import timedelta
import scipy.constants as const
import matplotlib.dates as mdates

# define hte directory for the data
# data folder direcotry
data_dir = r"C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Data"
# direrctory for saving results
base_dir = r"C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\25_06_24_Results"
# directory for the results folder to investigate for session 6
results_dir = r'C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\iv_curve_plots_20250404_211059_spring_3794347'
# directory for the site summary to read from
summary_dir = r"C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Data\25_05_01_Newsites_summary.xlsx"
# define the output directory
output_dir = r"C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined"

# Determine fixed x and y axis limits for all plots that plot for each module
y_limit_module = (0, 15)
x_limit_module = (0, 60)  # Assuming a reasonable range for combined voltages

# Determine fixed x and y axis limits for all plots that plot for the combined inverter
y_limit_inverter = (0, 17)
x_limit_inverter = (0, 1200)  # Adjust for combined voltages

# Option to dynamically calculate vth based on panel temperature
use_dynamic_vth = True  # Set to True to enable dynamic calculation, False to use thermal_voltage_25C

# Option to replace the panel temperature with the temperature, the reason to do this is that the module temperature looks too high but the ambient tmperature looks like module temperature
use_a_T = True  # Set to True to use ambient temperature, False to use module temperature

# define the plot template
axis_label_size = 20
axis_num_size = 20
text_size = 20
title_size = 22

# define the figure size for single plot
figure_size = (6, 6)
subplot_size_1_2 = (6, 6)
long_hoz_figsize = (12, 6)

# define the function to calculate the I0 at MPPT
def I0(I, V, Rs, Rsh, n, N, vth):
    # calculate the exponential term
    exp_term = np.exp(-(V + I * Rs) / (n * N * vth))
    # calculate the fraction term
    frac_term = n * N * vth / V
    # calculate hte numerator
    numerator = I*(1 + Rs/Rsh) - V/Rsh
    # calculate the denominator
    denominator = 1 - I * Rs / V
    # put them together
    I0 = numerator / denominator * frac_term * exp_term
    return I0

# define the function to calculate IL at MPPT
def IL(I, V, Rs, Rsh, n, N, vth, I0):
    # calculate the first term
    first_term = I * (1 + Rs/Rsh)
    # calculate the second term
    second_term = V / Rsh
    # calculate the third term
    third_term = I0*(np.exp((V + I * Rs) / (n * N * vth)) - 1)
    # put them together
    IL = first_term + second_term + third_term
    return IL

# define a list of systems that are single orientation
single_orientation_systems = [
    '4073264', '4162787', '3788787', '4184502',
    '4122216', '4111846', '4140175', '4093272',
    '4034376', '4123602', '4172746', '4093266',
    '4153809', '4112053', '3499407', '4186157']

# %% [markdown]
# # 2. Loop through all data

# %%
# Get all site_ids from the folder names in data_dir
site_folders = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
site_ids = [folder.split('_')[0] for folder in site_folders]
print(site_ids)
site_ids = ['3455043']
# site_ids = ['4111846']

# create a list of seasons to loop through
# seasons = ['spring', 'summer', 'autumn', 'winter']
seasons = ['summer']

# # Constants for vth calculation
boltzmann_constant = const.Boltzmann  # Boltzmann constant in J/K
electron_charge = const.e  # Elementary charge in C

# read the summary file to get the site_id and the season
summary_df = pd.read_excel(summary_dir, sheet_name='Sheet1')
print(summary_df.head())
# Out:
# ['3455043', '4002138', '4034376', '4073264', '4093266', '4093272', '4111492', '4111800', '4111846', '4112053', '4118327', '4122216', '4123602', '4140175', '4153809', '4162787', '4172746', '4173851', '4184502', '4186157', '4197100']
#    No  Site ID        Country  State     kWp  Number of modules  Module size  \
# 0   1  3455043      Australia    QLD   9.960               24.0          415
# 1   2  4002138      Australia    VIC   6.660               18.0          370
# 2   3  4034376      Australia     SA   6.650               14.0          475
# 3   4  4140175      Australia    NSW   6.600               15.0          440
# 4   5  4186157  North America  Texas  10.695               31.0          345
#
#      Opt                 Module Make                       Module  \
# 0   S440                      Q Cell       Q.PEAK DUO ML-G10+ 415
# 1   S440              Canadian solar                   CS3L-370MS
# 2   S500  JinkoSolar Holding Co. Ltd              JKM475N-60HL4-V
# 3  S500B          Trina Solar Energy  TSM-440NEG9R.28 (Vertex S+)
# 4   S440               Mission Solar          \t\nMSE345SX5T 345W
#
#                                           Address Orientation Shade  \
# 0            18 Greene Street, Newmarket, QLD, AU       Multi   Yes
# 1         184 Blind Creek Road, Cardigan, VIC, AU      Single    No
# 2        49 Weerana Road, Salisbury Plain, SA, AU      Single    No
# 3          4 Cromarty Rd, Soldiers Point NSW 2317      Single   Yes
# 4  2239 Cypress Pearl, San Antonio, TX 78232, USA      Single    No
#
#   PV Syst Module Data Module Datasheet Telemtry Data
# 0                 Yes              Yes           Yes
# 1                 Yes              Yes           Yes
# 2                 Yes              Yes           Yes
# 3                 Yes              Yes           Yes
# 4                 Yes              Yes           Yes

# %%
# for site_id in ['3794347']:
for site_id in site_ids:
    print(f"Processing site_id: {site_id}")

    #============= find the site_id directory =============
    for season in seasons:
    # for season in seasons:
        # Find the directory containing the site_id
        site_dir = [d for d in os.listdir(data_dir) if site_id in d][0]

        # Full path to the site directory
        site_dir = os.path.join(data_dir, site_dir)

        #============= Get the data =============
        # Define a mapping from season to a list of month names (all in lowercase)
        season_months_south = {
            'summer': ['december', 'january', 'february'],
            'autumn': ['march', 'april', 'may'],
            'winter': ['june', 'july', 'august'],
            'spring': ['september', 'october', 'november']
        }
        # define a mapping from season to a list of month names for northern hemisphere
        season_months_north = {
            'summer': ['june', 'july', 'august'],
            'autumn': ['september', 'october', 'november'],
            'winter': ['december', 'january', 'february'],
            'spring': ['march', 'april', 'may']
        }

        # look up the site id in the summary file to find the corresponding Country
        site_info = summary_df[summary_df['Site ID'] == int(site_id)]

        # print("Site info found:", site_info)

        if site_info['Country'].values[0] == 'Australia':
            # Use the southern hemisphere mapping
            season_months = season_months_south
        else:
            # Use the northern hemisphere mapping
            season_months = season_months_north

        # Ensure the season is in lowercase for matching
        season_lower = season.lower()

        # Find the folder that contains the season word or any month name corresponding to that season
        season_dir_candidates = [
            d for d in os.listdir(site_dir)
            if (season_lower in d.lower() or any(month in d.lower() for month in season_months.get(season_lower, [])))
        ]

        if not season_dir_candidates:
            raise ValueError("No folder found that contains the specified season or its corresponding months.")

        # Choose the first matching folder (or adjust the selection logic as needed)
        season_dir = season_dir_candidates[0]

        # Full path to the season directory
        season_dir = os.path.join(site_dir, season_dir)
        print("Season directory found:", season_dir)

        # Initialize empty lists to store the DataFrames and reporter IDs
        dataframes = []
        reporter_ids = []

        # Define a list of potential timestamp formats
        timestamp_formats = [
            "%Y-%m-%d %H:%M:%S",
            "%d/%m/%Y %H:%M",
            "%m/%d/%Y %H:%M",
            "%Y-%d-%m %H:%M:%S",
            None  # Let pandas infer formats
        ]

        # Get a list of CSV files in the season directory that contain "optimizer_data"
        csv_files = [f for f in os.listdir(season_dir) if 'optimizer_data' in f and f.endswith('.csv')]

        if not csv_files:
            raise ValueError("No CSV files found in season directory.")
            # go to the next season and site_id
            continue

        # If only one CSV file exists, check if it contains a 'reporter_id' column.
        if len(csv_files) == 1:
            file = csv_files[0]
            file_path = os.path.join(season_dir, file)
            df = pd.read_csv(file_path)
            
            if 'reporter_id' in df.columns:
                # Process the single CSV file by splitting it by reporter_id.
                unique_reporters = df['reporter_id'].unique()
                for reporter in unique_reporters:
                    df_rep = df[df['reporter_id'] == reporter].copy()
                    # Rename the first column to "Timestamp" if not already
                    if df_rep.columns[0] != 'Timestamp':
                        df_rep.rename(columns={df_rep.columns[0]: 'Timestamp'}, inplace=True)
                    
                    # Define a mapping for renaming relevant columns to include the reporter id
                    rename_map = {
                        'panel_current': f'panel_current_{reporter}',
                        'panel_voltage': f'panel_voltage_{reporter}',
                        'temperature': f'temperature_{reporter}',
                        'panel_temperature': f'panel_temperature_{reporter}',
                        'power': f'power_{reporter}'
                    }
                    df_rep.rename(columns=rename_map, inplace=True)
                    
                    # Convert the "Timestamp" column to datetime using potential formats
                    for fmt in timestamp_formats:
                        try:
                            df_rep['Timestamp'] = pd.to_datetime(df_rep['Timestamp'], format=fmt)
                            break
                        except (ValueError, TypeError):
                            pass
                    
                    # Set the index to the Timestamp
                    df_rep.set_index('Timestamp', inplace=True)
                    # Keep only the renamed columns
                    df_rep = df_rep[list(rename_map.values())]
                    dataframes.append(df_rep)
                    reporter_ids.append(str(reporter))
            else:
                # Single CSV file but without a 'reporter_id' column.
                # Treat the entire file as coming from a default reporter.
                default_reporter = "default"
                if df.columns[0] != 'Timestamp':
                    df.rename(columns={df.columns[0]: 'Timestamp'}, inplace=True)
                rename_map = {
                    'panel_current': f'panel_current_{default_reporter}',
                    'panel_voltage': f'panel_voltage_{default_reporter}',
                    'temperature': f'temperature_{default_reporter}',
                    'panel_temperature': f'panel_temperature_{default_reporter}',
                    'power': f'power_{default_reporter}'
                }
                df.rename(columns=rename_map, inplace=True)
                for fmt in timestamp_formats:
                    try:
                        df['Timestamp'] = pd.to_datetime(df['Timestamp'], format=fmt)
                        break
                    except (ValueError, TypeError):
                        pass
                df.set_index('Timestamp', inplace=True)
                df = df[list(rename_map.values())]
                dataframes.append(df)
                reporter_ids.append(default_reporter)
        else:
            # Multiple CSV files case (each file corresponding to one optimizer)
            for file in csv_files:
                file_path = os.path.join(season_dir, file)
                optimizer_data = pd.read_csv(file_path)
                
                # Extract the reporter_id from the file name (assuming it is the last part before the extension)
                reporter_id = file.split('_')[-1].split('.')[0]
                reporter_ids.append(reporter_id)
                
                optimizer_data.rename(columns={
                    'panel_current': f'panel_current_{reporter_id}',
                    'panel_voltage': f'panel_voltage_{reporter_id}',
                    'temperature': f'temperature_{reporter_id}',
                    'panel_temperature': f'panel_temperature_{reporter_id}',
                    'power': f'power_{reporter_id}'
                }, inplace=True)
                
                if optimizer_data.columns[0] != 'Timestamp':
                    optimizer_data.rename(columns={optimizer_data.columns[0]: 'Timestamp'}, inplace=True)
                
                for fmt in timestamp_formats:
                    try:
                        optimizer_data['Timestamp'] = pd.to_datetime(optimizer_data['Timestamp'], format=fmt)
                        break
                    except (ValueError, TypeError):
                        pass
                
                optimizer_data.set_index('Timestamp', inplace=True)
                optimizer_data = optimizer_data[[f'panel_current_{reporter_id}', f'panel_voltage_{reporter_id}',
                                                f'temperature_{reporter_id}', f'panel_temperature_{reporter_id}',
                                                f'power_{reporter_id}']]
                dataframes.append(optimizer_data)

        # Synchronize timestamps across all DataFrames:
        if dataframes:
            # Find the overlapping time window by using the maximum start time and the minimum end time.
            earliest_timestamp = max([df.index[0] for df in dataframes])
            latest_timestamp = min([df.index[-1] for df in dataframes])
            # Create a new index with a 5-minute frequency.
            new_index = pd.date_range(start=earliest_timestamp, end=latest_timestamp, freq='5T')
            
            # Reindex each DataFrame, inserting NaN for missing timestamps.
            for i in range(len(dataframes)):
                for index in new_index:
                    if index not in dataframes[i].index:
                        dataframes[i].loc[index] = np.nan
            
            # Merge all DataFrames on the Timestamp index.
            merged_data = pd.concat(dataframes, axis=1)
            # Reset the index so that Timestamp becomes a column.
            merged_data.reset_index(inplace=True)


        # remove any rows that contains Nan
        # merged_data.dropna(inplace=True)
        # print(merged_data)

        # Specify the number of days to plot
        num_days_to_plot = 10

        # Filter the data for the specified number of days
        start_date = pd.to_datetime(merged_data['Timestamp'].iloc[0])
        end_date = start_date + timedelta(days=num_days_to_plot)
        filtered_data = merged_data[(pd.to_datetime(merged_data['Timestamp']) >= start_date) & 
                                    (pd.to_datetime(merged_data['Timestamp']) < end_date)]
        first_month = pd.to_datetime(merged_data['Timestamp'].iloc[0]).strftime('%B')

        # print(filtered_data)

        # Create a 2x2 subplot for the data
        fig, axs = plt.subplots(2, 2, figsize=long_hoz_figsize)  # Use figure size from session 1

        # Add a figure-level title with site ID and season
        # fig.suptitle(f"Site ID: {site_id} | Season: {season}", fontsize=title_size)  # Use title_size

        fig.suptitle(f"Site ID: {site_id} | Month: {first_month}", fontsize=title_size)  # Use title_size

        # Plot all panel currents
        for reporter_id in reporter_ids:
            axs[0, 0].plot(filtered_data['Timestamp'], filtered_data[f'panel_current_{reporter_id}'])
        axs[0, 0].set_title('Panel Current', fontsize=title_size)
        axs[0, 0].set_xlabel('Time', fontsize=axis_label_size-5)
        axs[0, 0].set_ylabel('Current (A)', fontsize=axis_label_size-5)
        axs[0, 0].tick_params(axis='x', which='both', bottom=False, labelbottom=False, labelsize=axis_num_size)
        axs[0, 0].tick_params(axis='y', labelsize=axis_num_size)

        # Plot all panel voltages
        for reporter_id in reporter_ids:
            axs[0, 1].plot(filtered_data['Timestamp'], filtered_data[f'panel_voltage_{reporter_id}'])
        axs[0, 1].set_title('Panel Voltage', fontsize=title_size)
        axs[0, 1].set_xlabel('Time', fontsize=axis_label_size-5)
        axs[0, 1].set_ylabel('Voltage (V)', fontsize=axis_label_size-5)
        axs[0, 1].tick_params(axis='x', which='both', bottom=False, labelbottom=False, labelsize=axis_num_size)
        axs[0, 1].tick_params(axis='y', labelsize=axis_num_size)

        # Plot all temperatures
        for reporter_id in reporter_ids:
            axs[1, 0].plot(filtered_data['Timestamp'], filtered_data[f'temperature_{reporter_id}'])
        axs[1, 0].set_title('Temperature', fontsize=title_size)
        axs[1, 0].set_xlabel('Time', fontsize=axis_label_size-5)
        axs[1, 0].set_ylabel('Temperature (°C)', fontsize=axis_label_size-5)
        axs[1, 0].tick_params(axis='x', which='both', bottom=False, labelbottom=False, labelsize=axis_num_size)
        axs[1, 0].tick_params(axis='y', labelsize=axis_num_size)

        # Plot all panel temperatures
        for reporter_id in reporter_ids:
            axs[1, 1].plot(filtered_data['Timestamp'], filtered_data[f'panel_temperature_{reporter_id}'])
        axs[1, 1].set_title('Panel Temperature', fontsize=title_size)
        axs[1, 1].set_xlabel('Time', fontsize=axis_label_size-5)
        axs[1, 1].set_ylabel('Panel Temperature (°C)', fontsize=axis_label_size-5)
        axs[1, 1].tick_params(axis='x', which='both', bottom=False, labelbottom=False, labelsize=axis_num_size)
        axs[1, 1].tick_params(axis='y', labelsize=axis_num_size)

        # Adjust layout and show the plot
        plt.tight_layout(rect=[0, 0, 1, 0.95])  # Leave space for the suptitle
        plt.show()

        # Create a new figure with 3 rows, 1 column showing Panel Current, Voltage, and Temperature
        fig, axs = plt.subplots(3, 1, figsize=(12, 12))

        # Plot all panel currents
        for reporter_id in reporter_ids:
            axs[0].plot(filtered_data['Timestamp'], filtered_data[f'panel_current_{reporter_id}'], alpha=0.7)
        axs[0].set_title(f'Site ID: {site_id} | Month: {first_month}\nModule Current', fontsize=title_size)
        axs[0].set_ylabel('Current (A)', fontsize=axis_label_size)
        axs[0].tick_params(axis='x', which='both', bottom=False, labelbottom=False, labelsize=axis_num_size)
        axs[0].tick_params(axis='y', labelsize=axis_num_size)
        axs[0].grid(True, alpha=0.3)

        # Plot all panel voltages
        for reporter_id in reporter_ids:
            axs[1].plot(filtered_data['Timestamp'], filtered_data[f'panel_voltage_{reporter_id}'], alpha=0.7)
        axs[1].set_title('Module Voltage', fontsize=title_size)
        axs[1].set_ylabel('Voltage (V)', fontsize=axis_label_size)
        axs[1].tick_params(axis='x', which='both', bottom=False, labelbottom=False, labelsize=axis_num_size)
        axs[1].tick_params(axis='y', labelsize=axis_num_size)
        axs[1].grid(True, alpha=0.3)

        # Plot all temperatures (ambient temperature since use_a_T is True)
        for reporter_id in reporter_ids:
            axs[2].plot(filtered_data['Timestamp'], filtered_data[f'temperature_{reporter_id}'], alpha=0.7)
        axs[2].set_title('Module Temperature', fontsize=title_size)
        axs[2].set_xlabel('Time', fontsize=axis_label_size)
        axs[2].set_ylabel('Temperature (°C)', fontsize=axis_label_size)
        axs[2].xaxis.set_major_locator(mdates.DayLocator(interval=2))
        axs[2].xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
        axs[2].tick_params(axis='x', labelsize=axis_num_size)
        axs[2].tick_params(axis='y', labelsize=axis_num_size)
        axs[2].grid(True, alpha=0.3)

        plt.tight_layout()
        
        # Save the figure
        plot_file = os.path.join(output_dir, 'panel_data_timeseries.png')
        fig.savefig(plot_file, dpi=300)
        plt.show()
        print(f"Panel data timeseries plot exported to: {plot_file}")
        
        # create a new folder for the results, name it as the site_id and season, and the time now
        # now = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        # results_folder = os.path.join(base_dir, f"v_from_i_combined\{site_id}_{season}_{now}")
        # os.makedirs(results_folder, exist_ok=True)
        # first_month = pd.to_datetime(merged_data['Timestamp'].iloc[0]).strftime('%B')
        # now = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        # results_folder = os.path.join(base_dir, f"v_from_i_combined\\{site_id}_{first_month}_{now}")
        # os.makedirs(results_folder, exist_ok=True)
        # Create date-based folder structure
        date_folder = datetime.datetime.now().strftime("%y_%m_%d_Results")
        # Ensure we use the correct v_from_i_combined path
        v_from_i_combined_dir = r"C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined"
        date_results_dir = os.path.join(v_from_i_combined_dir, date_folder)
        os.makedirs(date_results_dir, exist_ok=True)
        
        first_month = pd.to_datetime(merged_data['Timestamp'].iloc[0]).strftime('%B')
        now = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        results_folder = os.path.join(date_results_dir, f"{site_id}_{first_month}_{now}")
        os.makedirs(results_folder, exist_ok=True)

        # save the figure to the results folder
        fig.savefig(os.path.join(results_folder, f"{site_id}_{season}_data.png"), dpi=300, bbox_inches='tight')
        plt.close(fig)  # Close the figure to free up memory

        if use_a_T:
            print("Using ambient temperature")
            # Remove any column whose name contains "panel_temperature"
            cols_to_drop = [col for col in merged_data.columns if 'panel_temperature' in col]
            merged_data.drop(columns=cols_to_drop, inplace=True)
            
            # For each column that contains "temperature", create a duplicate column 
            # with the name changed from "temperature" to "panel_temperature"
            for col in [col for col in merged_data.columns if 'temperature' in col]:
                new_col = col.replace('temperature', 'panel_temperature')
                merged_data[new_col] = merged_data[col]

        #============= Module parameter extraction =============
        # find the .PAN file in the site_dir
        pan_file = [f for f in os.listdir(site_dir) if f.endswith('.PAN')][0]

        # read the .PAN file
        pan_file_path = os.path.join(site_dir, pan_file)

        with open(pan_file_path, 'r') as f:
            pan_data = f.readlines()
            # find the line that contains the "RSeries"
            for line in pan_data:
                if 'RSerie' in line: # Note: The original code had 'RSeries' which might be a typo in the PAN file
                    series_resistance = float(line.split('=')[1].strip())
                    print(f"Series Resistance from PAN file: {series_resistance}")
            # find the line that contains the "RShunt"
            for line in pan_data:
                if 'RShunt' in line:
                    shunt_resistance = float(line.split('=')[1].strip())
                    print(f"Shunt Resistance from PAN file: {shunt_resistance}")
            # find the line that contains the "NCelS" as the number of cells in series
            for line in pan_data:
                if 'NCelS' in line:
                    num_cells_series = int(line.split('=')[1].strip())
                    print(f"Number of cells in series from PAN file: {num_cells_series}")
            # find the line that contains the "Gamma" as the ideality factor
            for line in pan_data:
                if 'Gamma' in line:
                    ideality_factor = float(line.split('=')[1].strip())
                    print(f"Ideality factor from PAN file: {ideality_factor}")
                    break  # Exit the loop after finding the ideality factor

        #============= Loop through timestep and reporter id anlaysis =============
        timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
        output_dir = results_folder
        os.makedirs(output_dir, exist_ok=True)

        image_files = []
        max_power_df_combined = pd.DataFrame(columns=['Timestamp', 'Max Voltage (V)', 'Max Current (A)', 'Max Power (W)', 'Voc (V)', 'Isc (A)'])
        pmppt_data = pd.DataFrame(columns=['Timestamp', 'Pmppt (W)'])
        module_param_df = pd.DataFrame(columns=[
            'Timestamp','Optimizer','I0','Isc','Voc','FF','Pmp','Imp','Vmp'
        ])
        iv_sum_data = pd.DataFrame(columns=['Timestamp', 'Sum of I*V (W)'])  # <-- Added for sum_iv

        currents = np.linspace(0, y_limit_inverter[1], 100)

        for idx in range(len(merged_data)):
            current_timestamp = pd.to_datetime(merged_data['Timestamp'].iloc[idx])

            # --- Filter: skip if all measured power is zero ---
            all_power_zero = all(
                merged_data.get(f'power_{optimiser}', pd.Series([0]*len(merged_data))).iloc[idx] == 0
                or np.isnan(merged_data.get(f'power_{optimiser}', pd.Series([0]*len(merged_data))).iloc[idx])
                for optimiser in reporter_ids
            )
            if all_power_zero:
                print(f"Time step {idx} skipped: all measured power is zero.")
                continue

            # --- Prepare for all three plots ---
            fig_long, axs_long = plt.subplots(1, 3, figsize=long_hoz_figsize)
            axs_long[0].set_title("Recorded MPP values", fontsize=title_size, pad=20)
            axs_long[0].set_xlim(x_limit_module)
            axs_long[0].set_ylim(y_limit_module)
            axs_long[0].set_xlabel('Voltage (V)', fontsize=axis_label_size)
            axs_long[0].set_ylabel('Current (A)', fontsize=axis_label_size)
            # axs_long[0].grid(True)
            axs_long[0].text(0.95, 0.95, '(a)', transform=axs_long[0].transAxes, fontsize=text_size, 
                ha='right', va='top')
            axs_long[0].tick_params(axis='both', labelsize=axis_num_size)

            axs_long[1].set_title("Reconstructed I-V curves", fontsize=title_size, pad=20)
            axs_long[1].set_xlim(x_limit_module)
            axs_long[1].set_ylim(y_limit_module)
            axs_long[1].set_xlabel('Voltage (V)', fontsize=axis_label_size)
            axs_long[1].set_ylabel('Current (A)', fontsize=axis_label_size)
            # axs_long[1].grid(True)
            axs_long[1].text(0.95, 0.95, '(b)', transform=axs_long[1].transAxes, fontsize=text_size, 
                ha='right', va='top')
            axs_long[1].tick_params(axis='both', labelsize=axis_num_size)

            axs_long[2].set_title("Series combined I-V curve", fontsize=title_size, pad=20)
            axs_long[2].set_xlim(x_limit_inverter)
            axs_long[2].set_ylim(y_limit_inverter)
            axs_long[2].set_xlabel('Voltage (V)', fontsize=axis_label_size)
            axs_long[2].set_ylabel('Current (A)', fontsize=axis_label_size)
            # axs_long[2].grid(True)
            axs_long[2].text(0.95, 0.95, '(c)', transform=axs_long[2].transAxes, fontsize=text_size, 
                ha='right', va='top')
            axs_long[2].tick_params(axis='both', labelsize=axis_num_size)

            combined_voltage = np.zeros_like(currents)
            valid_data_found = False
            sum_iv = 0
            max_power = np.nan  # Default in case no valid data

            for optimiser in reporter_ids:
                optimiser_voltage = merged_data[f'panel_voltage_{optimiser}']
                optimiser_current = merged_data[f'panel_current_{optimiser}']
                panel_temperature = merged_data[f'panel_temperature_{optimiser}']

                is_nan_or_zero = (
                    optimiser_voltage.iloc[idx] == 0 or
                    optimiser_current.iloc[idx] == 0 or
                    np.isnan(optimiser_voltage.iloc[idx]) or
                    np.isnan(optimiser_current.iloc[idx])
                )

                # Raw IV data (scatter)
                if not is_nan_or_zero:
                    panel_voltage = optimiser_voltage.iloc[idx]
                    panel_current = optimiser_current.iloc[idx]
                    axs_long[0].plot(panel_voltage, panel_current, 'ro', markersize=8, label=f'Opt {optimiser}')
                else:
                    axs_long[0].plot(0, 0, 'kx', label=f'Opt {optimiser} (no data)')

                # Reconstructed IV curves (model)
                if is_nan_or_zero:
                    voltage = np.zeros_like(currents)
                    axs_long[1].plot(voltage, currents, label=f'Opt {optimiser}')
                else:
                    valid_data_found = True
                    panel_temperature_kelvin = panel_temperature.iloc[idx] + 273.15
                    vth = boltzmann_constant * panel_temperature_kelvin / electron_charge if use_dynamic_vth else thermal_voltage_25C
                    panel_voltage = optimiser_voltage.iloc[idx]
                    panel_current = optimiser_current.iloc[idx]
                    sum_iv += panel_voltage * panel_current

                    I0_op = I0(panel_current, panel_voltage, series_resistance, shunt_resistance, ideality_factor, num_cells_series, vth)
                    IL_op = IL(panel_current, panel_voltage, series_resistance, shunt_resistance, ideality_factor, num_cells_series, vth, I0_op)
                    params = {
                        'photocurrent': IL_op,
                        'saturation_current': I0_op,
                        'resistance_series': series_resistance,
                        'resistance_shunt': shunt_resistance,
                        'nNsVth': ideality_factor * num_cells_series * vth
                    }
                    voltage = pvlib.pvsystem.v_from_i(
                        current=currents,
                        photocurrent=params['photocurrent'],
                        saturation_current=params['saturation_current'],
                        resistance_series=params['resistance_series'],
                        resistance_shunt=params['resistance_shunt'],
                        nNsVth=params['nNsVth']
                    )
                    axs_long[1].plot(voltage, currents, label=f'Opt {optimiser}')
                    axs_long[1].plot(panel_voltage, panel_current, 'ro')

                    # Combined IV curve (series)
                    results = pvlib.pvsystem.singlediode(**params)
                    isc = results['i_sc']
                    voc = results['v_oc']
                    pmp = results['p_mp']
                    imp = results['i_mp']
                    vmp = results['v_mp']
                    ff = (pmp / (isc * voc)) if (isc > 0 and voc > 0) else np.nan
                    voltage = np.where(currents > isc, 0, voltage)
                    combined_voltage += voltage

                    # append all five
                    module_param_df = pd.concat([module_param_df, pd.DataFrame({
                        'Timestamp': [current_timestamp],
                        'Optimizer': [optimiser],
                        'I0':        [I0_op],
                        'Isc':       [isc],
                        'Voc':       [voc],
                        'FF':        [ff],
                        'Pmp':       [pmp],
                        'Imp':       [imp],
                        'Vmp':       [vmp]
                    })], ignore_index=True)

                if is_nan_or_zero:
                    # no-data: record NaNs
                    module_param_df = pd.concat([module_param_df, pd.DataFrame({
                        'Timestamp': [current_timestamp],
                        'Optimizer': [optimiser],
                        'I0':        [np.nan],
                        'Isc':       [np.nan],
                        'Voc':       [np.nan],
                        'FF':        [np.nan],
                        'Pmp':       [np.nan],
                        'Imp':       [np.nan],
                        'Vmp':       [np.nan]
                    })], ignore_index=True)

            # Plot combined IV curve (series)
            if valid_data_found:
                power = combined_voltage * currents
                max_power_idx = np.argmax(power)
                max_voltage = combined_voltage[max_power_idx]
                max_current = currents[max_power_idx]
                max_power = power[max_power_idx]
                isc_combined = currents[np.where(combined_voltage > 0)[0][-1]]
                voc_combined = combined_voltage[np.where(currents == 0)[0][0]]

                axs_long[2].plot(combined_voltage, currents, label='Combined IV Curve')
                axs_long[2].plot(max_voltage, max_current, 'ro', label='Max Power Point')
                axs_long[2].plot(voc_combined, 0, 'go', label='Voc')
                axs_long[2].plot(0, isc_combined, 'bo', label='Isc')

                # Save max power and Pmppt
                current_timestamp = pd.to_datetime(merged_data['Timestamp'].iloc[idx])
                max_power_point = pd.DataFrame({
                    'Timestamp': [current_timestamp],
                    'Max Voltage (V)': [max_voltage],
                    'Max Current (A)': [max_current],
                    'Max Power (W)': [max_power],
                    'Voc (V)': [voc_combined],
                    'Isc (A)': [isc_combined]
                })
                max_power_df_combined = pd.concat([max_power_df_combined, max_power_point], ignore_index=True)
                pmppt_data = pd.concat([pmppt_data, pd.DataFrame({'Timestamp': [current_timestamp], 'Pmppt (W)': [max_power]})], ignore_index=True)

            # --- Save sum_iv for this timestep ---
            timestamp_title = pd.to_datetime(merged_data['Timestamp'].iloc[idx]).strftime('%Y-%m-%d %H:%M:%S')
            iv_sum_data = pd.concat([iv_sum_data, pd.DataFrame({'Timestamp': [timestamp_title], 'Sum of I*V (W)': [sum_iv]})], ignore_index=True)

            # --- Titles and save ---
            percentage_diff_at_time = 0
            if sum_iv != 0:
                percentage_diff_at_time = ((sum_iv - max_power) / sum_iv) * 100
            title_row1 = f"Site: {site_id} | {timestamp_title}"
            title_row2 = f"Sum of MPP: {sum_iv:.2f} W | Combined IV MPP: {max_power:.2f} W"
            title_row3 = f"% Diff: {percentage_diff_at_time:.2f}%"
            fig_long.suptitle(f"{title_row1}\n{title_row2}\n{title_row3}", fontsize=title_size)
            plt.tight_layout(rect=[0, 0, 1, 0.90])
            file_path = os.path.join(output_dir, f'long_horizontal_{timestamp_title.replace(":", "-").replace(" ", "_")}.png')
            plt.savefig(file_path, bbox_inches='tight')
            plt.close()
            image_files.append(file_path)
            print(f"Horizontal comparison plot saved: {file_path}")

        # --- Create a GIF from all horizontal comparison plots ---
        gif_path = os.path.join(output_dir, 'combined_iv_curves_long.gif')
        with imageio.get_writer(gif_path, mode='I', duration=200, loop=0) as writer:
            for filename in image_files:
                image = imageio.imread(filename)
                writer.append_data(image)
        print(f"GIF saved as: {gif_path}")

        # --- Save the sum of I*V data to an Excel file ---
        excel_path = os.path.join(output_dir, 'iv_sum_data.xlsx')
        iv_sum_data.to_excel(excel_path, index=False)
        print(f"Excel file saved as: {excel_path}")

        # --- Save the Pmppt data to an Excel file ---
        excel_file = os.path.join(output_dir, 'pmppt_data.xlsx')
        pmppt_data.to_excel(excel_file, index=False)
        print(f"Excel file saved as: {excel_file}")

        # --- Export J0 data to a CSV file with optimizer IDs as column names ---
        params_csv = os.path.join(output_dir, 'module_param_df.csv')
        module_param_df.to_csv(params_csv, index=False)
        print(f"Module parameters saved: {params_csv}")

        # ===================== Calcualte hte mismatching loss =====================
        # Merge the pmppt_data with the iv_sum_data
        combined_data = pd.concat([iv_sum_data, pmppt_data['Pmppt (W)']], axis=1)

        # Add season and site ID columns to the combined data
        combined_data['Season'] = season
        combined_data['Site ID'] = site_id

        # Export the combined data to an Excel file with season and site ID in the file name
        excel_file = os.path.join(output_dir, f'combined_data_{season}_{site_id}.xlsx')
        combined_data.to_excel(excel_file, index=False)

        print(f"Combined data exported to: {excel_file}")

        # Calculate the total energy of Sum of I*V and Pmppt
        sum_iv_E = combined_data['Sum of I*V (W)'].sum()
        pmppt_E = combined_data['Pmppt (W)'].sum()
        sum_mismatch = (sum_iv_E - pmppt_E) / sum_iv_E

        # Check if the lengths of Sum of I*V and Pmppt are the same
        if len(combined_data['Sum of I*V (W)']) == len(combined_data['Pmppt (W)']):
            print("The lengths of Sum of I*V and Pmppt are the same.")
        else:
            print("Warning: The lengths of Sum of I*V and Pmppt are not the same!")

        # Print the total energy for both
        print(f"Sum of I*V Energy: {sum_iv_E:.2f} W")
        print(f"Pmppt Energy: {pmppt_E:.2f} W")

        # Print the mean mismatch in percentage with 2 decimal places
        print(f"Sum mismatch: {sum_mismatch * 100:.2f}%")

        # ensure the timestamp is in datetime format
        combined_data['Timestamp'] = pd.to_datetime(combined_data['Timestamp'])

        # Plot the Pmppt and Sum of I*V
        fig, ax = plt.subplots(figsize=long_hoz_figsize)

        ax.plot(combined_data['Timestamp'],
                combined_data['Pmppt (W)'],
                label='Series connection',
                alpha=0.4)
        ax.plot(combined_data['Timestamp'],
                combined_data['Sum of I*V (W)'],
                label='Sum of maximum powers',
                alpha=0.4)

        ax.set_xlabel('Time', fontsize=axis_label_size)
        ax.set_ylabel('Power (W)', fontsize=axis_label_size)

        first_month = pd.to_datetime(combined_data['Timestamp'].iloc[0]).strftime('%B')
        ax.set_title(
            f'Site ID: {site_id}, Month: {first_month}\nMismatch: {sum_mismatch * 100:.2f}%',
            fontsize=title_size, pad=20
        )

        ax.legend(loc='upper right', fontsize=axis_num_size-5)

        # --- x-axis ticks every 2 days, but shorter & rotated ---
        # print(combined_data['Timestamp'].head())
        ax.xaxis.set_major_locator(mdates.DayLocator(interval=2))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
        ax.tick_params(axis='x', labelsize=axis_num_size)

        # y-axis label size
        ax.tick_params(axis='y', labelsize=axis_num_size)

        # tighten + more bottom padding
        plt.tight_layout()
        fig.subplots_adjust(bottom=0.20)

        # Save + show
        plot_file = os.path.join(output_dir, 'pmppt_vs_sum_iv.png')
        fig.savefig(plot_file, dpi=300)
        print(f"Plot exported to: {plot_file}")

        plt.show()

        # plot the percentage difference between Pmppt and Sum of I*V over time
        fig, ax = plt.subplots(figsize=long_hoz_figsize)
        percentage_diff = ((combined_data['Sum of I*V (W)'] - combined_data['Pmppt (W)']) / combined_data['Sum of I*V (W)']) * 100
        # if the sum of IV is less than 1, set the percentage difference to 0
        percentage_diff[combined_data['Sum of I*V (W)'] < 1] = 0
        abs_diff = (combined_data['Sum of I*V (W)'] - combined_data['Pmppt (W)']).abs()

        # Plot percentage difference on primary y-axis
        ax.plot(combined_data['Timestamp'], percentage_diff, label='Percentage Difference (%)', alpha=0.4, color='orange')
        ax.set_xlabel('Time', fontsize=axis_label_size)
        ax.set_ylabel('Percentage Difference (%)', fontsize=axis_label_size)

        # Create secondary y-axis for absolute difference
        ax2 = ax.twinx()
        ax2.plot(combined_data['Timestamp'], abs_diff, label='Absolute Difference (W)', alpha=0.4, color='blue')
        ax2.set_ylabel('Absolute Difference (W)', fontsize=axis_label_size)

        first_month = pd.to_datetime(combined_data['Timestamp'].iloc[0]).strftime('%B')
        ax.set_title(
            f'Site ID: {site_id}, Month: {first_month}\nMismatch: {sum_mismatch * 100:.2f}%',
            fontsize=title_size, pad=20
        )

        # Combine legends from both axes
        lines_1, labels_1 = ax.get_legend_handles_labels()
        lines_2, labels_2 = ax2.get_legend_handles_labels()
        ax2.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper right', fontsize=axis_num_size-5)

        ax.xaxis.set_major_locator(mdates.DayLocator(interval=2))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
        ax.tick_params(axis='x', labelsize=axis_num_size)
        ax.tick_params(axis='y', labelsize=axis_num_size)
        ax2.tick_params(axis='y', labelsize=axis_num_size)
        plt.tight_layout()
        fig.subplots_adjust(bottom=0.20)
        # Save + show
        plot_file = os.path.join(output_dir, 'percentage_difference.png')
        fig.savefig(plot_file, dpi=300)
        plt.show()
        print(f"Percentage difference plot exported to: {plot_file}")
# Out:
# Processing site_id: 3455043
# Season directory found: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Data\3455043\december
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:185: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   new_index = pd.date_range(start=earliest_timestamp, end=latest_timestamp, freq='5T')
# Panel data timeseries plot exported to: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\panel_data_timeseries.png
# Using ambient temperature
# Series Resistance from PAN file: 0.13
# Shunt Resistance from PAN file: 450.0
# Number of cells in series from PAN file: 66
# Ideality factor from PAN file: 1.045
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:514: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   module_param_df = pd.concat([module_param_df, pd.DataFrame({
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:500: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   module_param_df = pd.concat([module_param_df, pd.DataFrame({
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:551: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   max_power_df_combined = pd.concat([max_power_df_combined, max_power_point], ignore_index=True)
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:552: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pmppt_data = pd.concat([pmppt_data, pd.DataFrame({'Timestamp': [current_timestamp], 'Pmppt (W)': [max_power]})], ignore_index=True)
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:556: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   iv_sum_data = pd.concat([iv_sum_data, pd.DataFrame({'Timestamp': [timestamp_title], 'Sum of I*V (W)': [sum_iv]})], ignore_index=True)
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_04-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_05-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_06-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_07-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_08-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_09-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_10-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_11-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_12-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_13-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_14-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_15-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_16-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_17-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_18-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-15_19-00-00.png
# Time step 170 skipped: all measured power is zero.
# Time step 171 skipped: all measured power is zero.
# Time step 172 skipped: all measured power is zero.
# Time step 173 skipped: all measured power is zero.
# Time step 174 skipped: all measured power is zero.
# Time step 175 skipped: all measured power is zero.
# Time step 176 skipped: all measured power is zero.
# Time step 177 skipped: all measured power is zero.
# Time step 178 skipped: all measured power is zero.
# Time step 179 skipped: all measured power is zero.
# Time step 180 skipped: all measured power is zero.
# Time step 181 skipped: all measured power is zero.
# Time step 182 skipped: all measured power is zero.
# Time step 183 skipped: all measured power is zero.
# Time step 184 skipped: all measured power is zero.
# Time step 185 skipped: all measured power is zero.
# Time step 186 skipped: all measured power is zero.
# Time step 187 skipped: all measured power is zero.
# Time step 188 skipped: all measured power is zero.
# Time step 189 skipped: all measured power is zero.
# Time step 190 skipped: all measured power is zero.
# Time step 191 skipped: all measured power is zero.
# Time step 192 skipped: all measured power is zero.
# Time step 193 skipped: all measured power is zero.
# Time step 194 skipped: all measured power is zero.
# Time step 195 skipped: all measured power is zero.
# Time step 196 skipped: all measured power is zero.
# Time step 197 skipped: all measured power is zero.
# Time step 198 skipped: all measured power is zero.
# Time step 199 skipped: all measured power is zero.
# Time step 200 skipped: all measured power is zero.
# Time step 201 skipped: all measured power is zero.
# Time step 202 skipped: all measured power is zero.
# Time step 203 skipped: all measured power is zero.
# Time step 204 skipped: all measured power is zero.
# Time step 205 skipped: all measured power is zero.
# Time step 206 skipped: all measured power is zero.
# Time step 207 skipped: all measured power is zero.
# Time step 208 skipped: all measured power is zero.
# Time step 209 skipped: all measured power is zero.
# Time step 210 skipped: all measured power is zero.
# Time step 211 skipped: all measured power is zero.
# Time step 212 skipped: all measured power is zero.
# Time step 213 skipped: all measured power is zero.
# Time step 214 skipped: all measured power is zero.
# Time step 215 skipped: all measured power is zero.
# Time step 216 skipped: all measured power is zero.
# Time step 217 skipped: all measured power is zero.
# Time step 218 skipped: all measured power is zero.
# Time step 219 skipped: all measured power is zero.
# Time step 220 skipped: all measured power is zero.
# Time step 221 skipped: all measured power is zero.
# Time step 222 skipped: all measured power is zero.
# Time step 223 skipped: all measured power is zero.
# Time step 224 skipped: all measured power is zero.
# Time step 225 skipped: all measured power is zero.
# Time step 226 skipped: all measured power is zero.
# Time step 227 skipped: all measured power is zero.
# Time step 228 skipped: all measured power is zero.
# Time step 229 skipped: all measured power is zero.
# Time step 230 skipped: all measured power is zero.
# Time step 231 skipped: all measured power is zero.
# Time step 232 skipped: all measured power is zero.
# Time step 233 skipped: all measured power is zero.
# Time step 234 skipped: all measured power is zero.
# Time step 235 skipped: all measured power is zero.
# Time step 236 skipped: all measured power is zero.
# Time step 237 skipped: all measured power is zero.
# Time step 238 skipped: all measured power is zero.
# Time step 239 skipped: all measured power is zero.
# Time step 240 skipped: all measured power is zero.
# Time step 241 skipped: all measured power is zero.
# Time step 242 skipped: all measured power is zero.
# Time step 243 skipped: all measured power is zero.
# Time step 244 skipped: all measured power is zero.
# Time step 245 skipped: all measured power is zero.
# Time step 246 skipped: all measured power is zero.
# Time step 247 skipped: all measured power is zero.
# Time step 248 skipped: all measured power is zero.
# Time step 249 skipped: all measured power is zero.
# Time step 250 skipped: all measured power is zero.
# Time step 251 skipped: all measured power is zero.
# Time step 252 skipped: all measured power is zero.
# Time step 253 skipped: all measured power is zero.
# Time step 254 skipped: all measured power is zero.
# Time step 255 skipped: all measured power is zero.
# Time step 256 skipped: all measured power is zero.
# Time step 257 skipped: all measured power is zero.
# Time step 258 skipped: all measured power is zero.
# Time step 259 skipped: all measured power is zero.
# Time step 260 skipped: all measured power is zero.
# Time step 261 skipped: all measured power is zero.
# Time step 262 skipped: all measured power is zero.
# Time step 263 skipped: all measured power is zero.
# Time step 264 skipped: all measured power is zero.
# Time step 265 skipped: all measured power is zero.
# Time step 266 skipped: all measured power is zero.
# Time step 267 skipped: all measured power is zero.
# Time step 268 skipped: all measured power is zero.
# Time step 269 skipped: all measured power is zero.
# Time step 270 skipped: all measured power is zero.
# Time step 271 skipped: all measured power is zero.
# Time step 272 skipped: all measured power is zero.
# Time step 273 skipped: all measured power is zero.
# Time step 274 skipped: all measured power is zero.
# Time step 275 skipped: all measured power is zero.
# Time step 276 skipped: all measured power is zero.
# Time step 277 skipped: all measured power is zero.
# Time step 278 skipped: all measured power is zero.
# Time step 279 skipped: all measured power is zero.
# Time step 280 skipped: all measured power is zero.
# Time step 281 skipped: all measured power is zero.
# Time step 282 skipped: all measured power is zero.
# Time step 283 skipped: all measured power is zero.
# Time step 284 skipped: all measured power is zero.
# Time step 285 skipped: all measured power is zero.
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-16_04-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-16_04-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-16_04-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-16_05-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-16_05-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-16_05-10-00.png
# ...
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_13-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_13-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_13-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_13-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_13-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_13-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_14-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_15-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_16-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-45-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-50-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_17-55-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-00-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-05-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-10-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-15-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-20-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-25-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-30-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-35-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-40-00.png
# Horizontal comparison plot saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\long_horizontal_2024-12-24_18-45-00.png
# C:\Users\z5183876\AppData\Local\Temp\ipykernel_38216\3899909136.py:577: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# GIF saved as: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\combined_iv_curves_long.gif
# Excel file saved as: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\iv_sum_data.xlsx
# Excel file saved as: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\pmppt_data.xlsx
# Module parameters saved: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\module_param_df.csv
# Combined data exported to: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\combined_data_summer_3455043.xlsx
# The lengths of Sum of I*V and Pmppt are the same.
# Sum of I*V Energy: 5005778.42 W
# Pmppt Energy: 4354269.66 W
# Sum mismatch: 13.02%
# Plot exported to: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\pmppt_vs_sum_iv.png
# Percentage difference plot exported to: C:\Users\z5183876\OneDrive - UNSW\Documents\GitHub\24_09_24_Solar_Edge\Results\v_from_i_combined\25_11_26_Results\3455043_December_20251126_210355\percentage_difference.png
